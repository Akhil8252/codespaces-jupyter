# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/workspaces/machine_learning_codespaces-jupyter/data/customer.csv")

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 6    18    Male     Good    School        No
# 46   64  Female     Poor        PG        No
# 45   61    Male     Poor        PG       Yes
# 47   38  Female     Good        PG       Yes
# 29   83  Female  Average        UG       Yes

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X_train
# Out:
#     age  gender
# 14   15    Male
# 31   22  Female
# 15   75    Male
# 2    70  Female
# 26   53  Female
# 47   38  Female
# 22   18  Female
# 48   39  Female
# 35   74    Male
# 43   27    Male
# 37   94    Male
# 10   98  Female
# 4    16  Female
# 36   34  Female
# 9    74    Male
# 34   86    Male
# 8    65  Female
# 29   83  Female
# 0    30  Female
# 16   59    Male
# 40   39    Male
# 30   73    Male
# 17   22  Female
# 27   69  Female
# 3    72  Female
# 49   25  Female
# 12   51    Male
# 33   89  Female
# 24   16  Female
# 28   48    Male
# 42   30  Female
# 32   92    Male
# 39   76    Male
# 46   64  Female
# 18   19    Male
# 23   96  Female
# 11   74    Male
# 13   57  Female
# 6    18    Male
# 38   45  Female

# %%
oe = OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 oe.fit(X_train)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:1495, in OrdinalEncoder.fit(self, X, y)
#    1488     raise TypeError(
#    1489         "unknown_value should only be set when "
#    1490         "handle_unknown is 'use_encoded_value', "
#    1491         f"got {self.unknown_value}."
#    1492     )
#    1494 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1495 fit_results = self._fit(
#    1496     X,
#    1497     handle_unknown=self.handle_unknown,
#    1498     force_all_finite="allow-nan",
#    1499     return_and_ignore_missing_for_infrequent=True,
#    1500 )
#    1501 self._missing_indices = fit_results["missing_indices"]
#    1503 cardinalities = [len(categories) for categories in self.categories_]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:113, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#     110 else:
#     111     Xi_dtype = Xi.dtype
# --> 113 cats = np.array(self.categories[i], dtype=Xi_dtype)
#     114 if (
#     115     cats.dtype == object
#     116     and isinstance(cats[0], bytes)
#     117     and Xi.dtype.kind != "S"
#     118 ):
#     119     msg = (
#     120         f"In column {i}, the predefined categories have type 'bytes'"
#     121         " which is incompatible with values of type"
#     122         f" '{type(Xi[0]).__name__}'."
#     123     )
#
# ValueError: invalid literal for int() with base 10: 'Poor'
